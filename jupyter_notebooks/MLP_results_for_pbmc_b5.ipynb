# %% [markdown]
# # Feed Forward Neural Network

# %%
import sys  
sys.path.insert(0, '../scripts')

# %%
dataset_train = '../dataset/68kPBMC_processed.h5ad'
dataset_test = '../dataset/smartseq2.h5ad'

# %%
import pickle
from utils import *

# %%
import scanpy as sc
import os
from numpy.random import seed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from sklearn import metrics

# %%
adata_train, adata_test = train_test_split(sc.read(dataset_train), train_frac=0.80)
# adata_test=sc.read(it_clust_dataset_test)

# %%
len(adata_train.to_df())
# Out:
# 54840

# %%
print("Starting preprocessing...")
train_dic = preprocess(adata_train, min_cells=0,min_genes=0, get_hvgs = True, scale_and_hvgs = True, calculate_hvg_and_log1p = False)
test_dic = preprocess(adata_test, min_cells=0, min_genes=0)
# Out:
# Starting preprocessing...
# /Users/anunay.y/personal/SingleCellClassification/SCC/lib/python3.9/site-packages/scanpy/preprocessing/_normalization.py:197: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# /Users/anunay.y/personal/SingleCellClassification/SCC/lib/python3.9/site-packages/scanpy/preprocessing/_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
col= [i for i in train_dic['hvg'].index]
print(col)
# Out:
# ['AL627309.1', 'RP11-54O7.1', 'RP11-54O7.17', 'HES4', 'ISG15', 'TNFRSF18', 'C1orf233', 'C1orf222', 'GABRD', 'PLCH2', 'RP3-395M20.7', 'LINC01134', 'NPHP4', 'SLC2A7', 'RBP7', 'KIF1B', 'AGTRAP', 'MTHFR', 'NPPA-AS1', 'KIAA2013', 'PLOD1', 'TNFRSF1B', 'EFHD2', 'CTRC', 'PLEKHM2', 'EPHA2', 'PADI2', 'PADI4', 'ARHGEF10L', 'ALDH4A1', 'RP1-43E13.2', 'CDA', 'RP3-329E20.2', 'HSPG2', 'C1QA', 'C1QC', 'C1QB', 'EPHB2', 'RP5-1057J7.6', 'E2F2', 'ID3', 'CLIC4', 'RUNX3', 'PAQR7', 'EXTL1', 'ZNF593', 'ZNF683', 'FAM46B', 'SLC9A1', 'FGR', 'IFI6', 'PTAFR', 'RP5-1092A3.5', 'RP11-442N24__B.1', 'SDC3', 'ZCCHC17', 'SERINC2', 'RP11-73M7.9', 'SPOCD1', 'KIAA1522', 'PHC2', 'TFAP2E', 'EVA1B', 'CSF3R', 'LINC01137', 'ZC3H12A', 'MYCL', 'MFSD2A', 'KCNQ4', 'KDM4A-AS1', 'CCDC24', 'SLC6A9', 'HPDL', 'MAST2', 'LURAP1', 'FAAH', 'LINC00853', 'PDZK1IP1', 'TAL1', 'PODN', 'SLC1A7', 'RP11-117D22.2', 'AL161915.1', 'C1orf177', 'RP11-90C4.1', 'JUN', 'EFCAB7', 'CACHD1', 'AK4', 'WLS', 'RP4-677H15.4', 'ST6GALNAC3', 'NEXN-AS1', 'NEXN', 'RP5-887A10.1', 'PKN2', 'DBT', 'RP11-305E17.6', 'AC093157.1', 'RP11-364B6.1', 'RP11-356N1.2', 'TAF13', 'PSRC1', 'SORT1', 'FAM212B', 'FAM212B-AS1', 'RP11-88H9.2', 'CTTNBP2NL', 'RHOC', 'OLFML3', 'AL136376.1', 'RP
STEAP3', 'TFCP2L1', 'AC068282.3', 'PROC', 'MYO7B', 'PTPN18', 'TMEM163', 'AC011893.3', 'HNMT', 'AC092620.3', 'GPD2', 'AC019186.1', 'RP11-1152H14.1', 'GRB14', 'SCN9A', 'BBS5', 'KLHL23', 'TLK1', 'DLX2', 'AC078883.3', 'MLTK', 'SCRN3', 'AC096649.2', 'RP11-171I2.5', 'RP11-366L5.1', 'TFPI', 'C2orf88', 'RP11-647K16.1', 'NAB1', 'MYO1B', 'SDPR', 'DNAH7', 'SATB2', 'AC005037.3', 'MPP4', 'NRP2', 'AC007879.2', 'IDH1-AS1', 'KANSL1L', 'RP11-260M2.1', 'BARD1', 'TNS1', 'CXCR2', 'GPBAR1', 'SLC11A1', 'VIL1', 'PLCD4', 'ZNF142', 'TTLL4', 'CYP27A1', 'TUBA4A', 'PTPRN', 'SLC4A3', 'CTD-2308L22.1', 'AC073641.2', 'IRS1', 'RP11-395N3.2', 'PID1', 'ITM2C', 'NPPC', 'GIGYF2', 'RAMP1', 'GPR35', 'BOK', 'RP11-97C16.1', 'AC026202.3', 'GRM7-AS1', 'OXTR', 'SETD5-AS1', 'TTLL3', 'PRRT3-AS1', 'AC022007.5', 'RP11-169K17.3', 'TMEM40', 'CAND2', 'RPL32', 'RP11-434D12. ...

# %%
train_adata_pp =  train_dic['data']
print(train_dic['hvg'])
test_adata_pp =  test_dic['data'][:, intersection(col, test_dic['data'].var.index)]
train_adata_pp = train_dic['data'][:, intersection(col, train_dic['data'].var.index)]
# Out:
# AL627309.1      True
# RP11-54O7.1     True
# RP11-54O7.17    True
# HES4            True
# ISG15           True
#                 ...
# AP001469.9      True
# S100B           True
# MT-ND2          True
# MT-CO1          True
# AC011043.1      True
# Name: highly_variable, Length: 2000, dtype: bool

# %%
train_df = train_adata_pp.to_df()
test_df = test_adata_pp.to_df()

# %%
## taking common genes
print("Taking common genes...")
final_columns = list(set(train_df.columns).intersection(set(test_df.columns)))
print('Common columns', len(final_columns))
final_columns = [i for i in final_columns if i != 'celltype'] 
train_df = train_df[final_columns]
test_df = test_df[final_columns]
# Out:
# Taking common genes...
# Common columns 2000

# %%
y_train = train_adata_pp.obs.celltype.to_list()
y_test = test_adata_pp.obs.celltype.to_list()

# %%
print(len(y_train))
print(len(y_test))
# Out:
# 54840
# 13711

# %%
X_train = train_df.to_numpy()
X_test = test_df.to_numpy()

# %%
X_test.shape
# Out:
# (13711, 2000)

# %%
mapped_data = get_data_mapping(X_train, y_train)

# %%
for i in mapped_data:
    print(i, len(mapped_data[i]))
# Out:
# CD56+ NK 4633
# CD14+ Monocyte 2628
# CD8+ Cytotoxic T 9177
# CD4+/CD25 T Reg 11370
# CD8+/CD45RA+ Naive Cytotoxic 17561
# CD4+/CD45RA+/CD25- Naive T 2220
# Dendritic 1508
# CD19+ B 3031
# CD4+/CD45RO+ Memory 2490
# CD34+ 204
# CD4+ T Helper2 18

# %%
mapping = get_mapping(y_train)

# %%
y_test_lab = convert_y_to_mapping(y_test, mapping)
y_test_lab = np.array(y_test_lab)

# %%
y_train_lab = convert_y_to_mapping(y_train, mapping)
y_train_lab = np.array(y_train_lab)

# %%
from sklearn.neural_network import MLPClassifier
train_model(MLPClassifier(random_state= 3, max_iter=300, verbose=True), X_train, y_train, X_test, y_test, mapping)
# Out:
# Iteration 1, loss = 1.93357332
# Iteration 2, loss = 1.69377945
# Iteration 3, loss = 1.55791618
# Iteration 4, loss = 1.42126229
# Iteration 5, loss = 1.32648970
# Iteration 6, loss = 1.24927596
# Iteration 7, loss = 1.17741226
# Iteration 8, loss = 1.10668093
# Iteration 9, loss = 1.04889214
# Iteration 10, loss = 1.00753676
# Iteration 11, loss = 0.96955319
# Iteration 12, loss = 0.92648782
# Iteration 13, loss = 0.89226175
# Iteration 14, loss = 0.85378911
# Iteration 15, loss = 0.83647518
# Iteration 16, loss = 0.80013147
# Iteration 17, loss = 0.77812291
# Iteration 18, loss = 0.75559933
# Iteration 19, loss = 0.72709935
# Iteration 20, loss = 0.70131031
# Iteration 21, loss = 0.68778612
# Iteration 22, loss = 0.66340083
# Iteration 23, loss = 0.66051341
# Iteration 24, loss = 0.64440788
# Iteration 25, loss = 0.63124317
# Iteration 26, loss = 0.60950150
# Iteration 27, loss = 0.59863304
# Iteration 28, loss = 0.58005391
# Iteration 29, loss = 0.56163442
# Iteration 30, loss = 0.55304324
# Iteration 31, loss = 0.54059123
# Iteration 32, loss = 0.53260456
# Iteration 33, loss = 0.51340602
# Iteration 34, loss = 0.50264259
# Iteration 35, loss = 0.49427373
# Iteration 36, loss = 0.48726625
# Iteration 37, loss = 0.47970235
# Iteration 38, loss = 0.46619022
# Iteration 39, loss = 0.45622595
# Iteration 40, loss = 0.44773634
# Iteration 41, loss = 0.44585886
# Iteration 42, loss = 0.43106241
# Iteration 43, loss = 0.42179498
# Iteration 44, loss = 0.41953606
# Iteration 45, loss = 0.41850107
# Iteration 46, loss = 0.40656495
# Iteration 47, loss = 0.39467009
# Iteration 48, loss = 0.39208178
# Iteration 49, loss = 0.38271258
# Iteration 50, loss = 0.37755276
# Iteration 51, loss = 0.37915504
# Iteration 52, loss = 0.36878990
# Iteration 53, loss = 0.36387436
# Iteration 54, loss = 0.35688911
# Iteration 55, loss = 0.35206055
# Iteration 56, loss = 0.34787883
# Iteration 57, loss = 0.34399883
# Iteration 58, loss = 0.34055464
# Iteration 59, loss = 0.34043944
# Iteration 60, loss = 0.37256251
# Iteration 61, loss = 0.36223357
# Iteration 62, loss = 0.33786584
# Iteration 63, loss = 0.32801999
# Iteration 64, loss = 0.32440715
# Iteration 65, loss = 0.32092975
# Iteration 66, loss = 0.31845481
# Iteration 67, loss = 0.31612973
# Iteration 68, loss = 0.31354671
# Iteration 69, loss = 0.31156945
# Iteration 70, loss = 0.31029996
# Iteration 71, loss = 0.30696103
# Iteration 72, loss = 0.30414929
# Iteration 73, loss = 0.30815158
# Iteration 74, loss = 0.31244917
# Iteration 75, loss = 0.30237790
# Iteration 76, loss = 0.29632899
# Iteration 77, loss = 0.29272017
# Iteration 78, loss = 0.29024571
# Iteration 79, loss = 0.28679369
# Iteration 80, loss = 0.28357683
# Iteration 255, loss = 0.11159185
# Iteration 256, loss = 0.10850989
# Iteration 257, loss = 0.10771458
# Iteration 258, loss = 0.10697527
# Iteration 259, loss = 0.10691755
# Iteration 260, loss = 0.10576539
# Iteration 261, loss = 0.10563653
# Iteration 262, loss = 0.10546375
# Iteration 263, loss = 0.10472557
# Iteration 264, loss = 0.10467205
# Iteration 265, loss = 0.10460737
# Iteration 266, loss = 0.10339421
# Iteration 267, loss = 0.10343777
# Iteration 268, loss = 0.10391317
# Iteration 269, loss = 0.11140440
# Iteration 270, loss = 0.12556089
# Iteration 271, loss = 0.12911498
# Iteration 272, loss = 0.12324769
# Iteration 273, loss = 0.12893094
# Iteration 274, loss = 0.10492394
# Iteration 275, loss = 0.10234895
# Iteration 276, loss = 0.10171232
# Iteration 277, loss = 0.10145833
# Iteration 278, loss = 0.10084986
# Iteration 279, loss = 0.10061531
# Iteration 280, loss = 0.10012075
# Iteration 281, loss = 0.09991372
# Iteration 282, loss = 0.10012483
# Iteration 283, loss = 0.10003152
# Iteration 284, loss = 0.09943847
# Iteration 285, loss = 0.09987366
# Iteration 286, loss = 0.09871926
# Iteration 287, loss = 0.09881250
# Iteration 288, loss = 0.09791697
# Iteration 289, loss = 0.09859139
# Iteration 290, loss = 0.09817619
# Iteration 291, loss = 0.09801888
# Iteration 292, loss = 0.09648044
# Iteration 293, loss = 0.09754974
# Iteration 294, loss = 0.09681369
# Iteration 295, loss = 0.09633816
# Iteration 296, loss = 0.09576713
# Iteration 297, loss = 0.09587849
# Iteration 298, loss = 0.09426572
# Iteration 299, loss = 0.09451048
# Iteration 300, loss = 0.09496171
# /Users/anunay.y/personal/SingleCellClassification/SCC/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/anunay.y/personal/SingleCellClassification/SCC/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/anunay.y/personal/SingleCellClassification/SCC/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                               precision    recall  f1-score   support
#
#               CD4+ T Helper2       0.88      0.72      0.79       678
#          CD4+/CD45RO+ Memory       0.95      0.15      0.25       785
#                        CD34+       0.97      0.87      0.92        45
# CD8+/CD45RA+ Naive Cytotoxic       0.00      0.00      0.00         1
#               CD14+ Monocyte       0.51      0.71      0.60      2740
#                      CD19+ B       0.20      0.67      0.30       571
#   CD4+/CD45RA+/CD25- Naive T       0.46      0.37      0.41       635
#              CD4+/CD25 T Reg       0.44      0.29      0.35      1226
#             CD8+ Cytotoxic T       0.65      0.40      0.50      2268
#                    Dendritic       0.70      0.73      0.72      4407
#                     CD56+ NK       0.00      0.00      0.00       355
#
#                     accuracy                           0.56     13711
#                    macro avg       0.52      0.44      0.44     13711
#                 weighted avg       0.61      0.56      0.55     13711
# /Users/anunay.y/personal/SingleCellClassification/SCC/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
calculate_freq(y_test)
# Out:
# {'Dendritic': 355,
#  'CD8+/CD45RA+ Naive Cytotoxic': 4407,
#  'CD14+ Monocyte': 678,
#  'CD19+ B': 785,
#  'CD4+/CD25 T Reg': 2740,
#  'CD4+/CD45RA+/CD25- Naive T': 571,
#  'CD56+ NK': 1226,
#  'CD8+ Cytotoxic T': 2268,
#  'CD4+/CD45RO+ Memory': 635,
#  'CD34+': 45,
#  'CD4+ T Helper2': 1}
